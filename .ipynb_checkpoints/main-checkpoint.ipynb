# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
roll_number = pd.read_csv("new_rolls.csv")
roll_numbers = roll_number["roll_numbers"].values

# %% [markdown]
# # GPA Scrapper

# %%
url = "https://portals.au.edu.pk/auresult/"

headers = {
    "Host": "portals.au.edu.pk",
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64; rv:121.0) Gecko/20100101 Firefox/121.0"
}

data_list = []

for roll in roll_numbers:
    print("\nFetching Result of: ", roll)
    
    payload = {
        "__EVENTTARGET": "",
        "__EVENTARGUMENT": "",
        "__VIEWSTATE": "",
        "__VIEWSTATEGENERATOR": "",
        "ctl00$AUContent$txt_regid": str(roll),
        "__ASYNCPOST": "true",
        "ctl00$AUContent$btnShow": "Search Result"
    }
    
    response = requests.post(url, headers=headers, data=payload)
    print(response.status_code)
    
    soup = BeautifulSoup(response.text, 'lxml')
    
    # Find all tables on the page
    tables = soup.find_all('table')
    
    # Initialize a set to store unique data
    unique_data = set()
    
    name_pattern = re.compile(r'Name\s*:\s*([\w\s]+)')
    gpa_pattern = re.compile(r'GPA\s*:\s*([\d.]+)')
    
    
    
    # Iterate through all tables
    if len(tables) >2 :
        for table in tables:
            # Iterate over each row in the table (skip the header row if necessary)
            for row in table.find_all('tr'):
                # Extract the text from each cell in the row
                # and add it to a list representing that row
                cols = row.find_all('td')
                cols = [ele.text.strip() for ele in cols]
                # Ensure that you have data (ignore empty/invalid rows)
                # print(cols)
                
                name_match = name_pattern.search(' '.join(cols))
                gpa_match = gpa_pattern.search(' '.join(cols))
                
                if name_match:
                    name = name_match.group(1).split("\n")[0]
                        
                if gpa_match:
                    gpa= gpa_match.group(1)
    else:
        name = None
        gpa = None
        
    data_list.append({"Roll Number": roll, "Name": name, "GPA": gpa})
    
df = pd.DataFrame(data_list)
df.to_csv("result_data.csv", index=False)
cleaned = df.dropna()
cleaned['GPA'] = cleaned['GPA'].astype(float)

sns.distplot(cleaned['GPA'])
cleaned.plot(x='Name', y='GPA', kind='bar', legend=False)
# Out:
# Fetching Result of:  202010
# 200
#
# Fetching Result of:  212141
# 200
#
# Fetching Result of:  220952
# 200
#
# Fetching Result of:  220953
# 200
#
# Fetching Result of:  220954
# 200
#
# Fetching Result of:  220955
# 200
#
# Fetching Result of:  220958
# 200
#
# Fetching Result of:  220959
# 200
#
# Fetching Result of:  220960
# 200
#
# Fetching Result of:  220961
# 200
#
# Fetching Result of:  220962
# 200
#
# Fetching Result of:  220963
# 200
#
# Fetching Result of:  220964
# 200
#
# Fetching Result of:  220965
# 200
#
# Fetching Result of:  220966
# 200
#
# Fetching Result of:  220967
# 200
#
# Fetching Result of:  220968
# 200
#
# Fetching Result of:  220969
# 200
#
# Fetching Result of:  220970
# 200
#
# Fetching Result of:  220971
# 200
#
# Fetching Result of:  220972
# 200
#
# Fetching Result of:  220973
# 200
#
# Fetching Result of:  220974
# 200
#
# Fetching Result of:  220975
# 200
#
# Fetching Result of:  220976
# 200
#
# Fetching Result of:  220977
# 200
#
# Fetching Result of:  220978
# 200
#
# Fetching Result of:  220979
# 200
#
# Fetching Result of:  220980
# 200
#
# Fetching Result of:  220981
# 200
#
# Fetching Result of:  220982
# 200
#
# Fetching Result of:  220983
# 200
#
# Fetching Result of:  220984
# 200
#
# Fetching Result of:  220985
# 200
#
# Fetching Result of:  220986
# 200
#
# Fetching Result of:  220989
# 200
#
# Fetching Result of:  220990
# 200
#
# Fetching Result of:  220991
# 200
#
# Fetching Result of:  220992
# 200
#
# Fetching Result of:  220993
# 200
#
# Fetching Result of:  220997
# 200
#
# Fetching Result of:  220998
# 200
#
# Fetching Result of:  220999
# 200
#
# Fetching Result of:  221000
# 200
#
# Fetching Result of:  221001
# 200
#
# Fetching Result of:  221002
# 200
#
# Fetching Result of:  221003
# 200
#
# Fetching Result of:  221004
# 200
#
# Fetching Result of:  221005
# 200
#
# Fetching Result of:  221006
# 200
#
# Fetching Result of:  221574
# 200
#
# Fetching Result of:  222606
# 200

# %% [markdown]
# # Subjects Grade and Gpa Scrapper

# %%
url = "https://portals.au.edu.pk/auresult/"

headers = {
    "Host": "portals.au.edu.pk",
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64; rv:121.0) Gecko/20100101 Firefox/121.0"
}

data_list = []

for i, roll in enumerate(roll_numbers):
    subjects = {}
    print("\nFetching Result of: ", roll)
    
    subjects["name"] = roll_number.iloc[i]["names"]
    subjects["roll_number"] = roll_number.iloc[i]["roll_numbers"]
    
    payload = {
        "__EVENTTARGET": "",
        "__EVENTARGUMENT": "",
        "__VIEWSTATE": "",
        "__VIEWSTATEGENERATOR": "",
        "ctl00$AUContent$txt_regid": str(roll),
        "__ASYNCPOST": "true",
        "ctl00$AUContent$btnShow": "Search Result"
    }
    
    response = requests.post(url, headers=headers, data=payload)
    print(response.status_code)
    
    soup = BeautifulSoup(response.text, 'lxml')
    # Find all tables on the page
    tables = soup.find_all('table')
    

    # Iterate through all tables
    if len(tables) >2:
        for row in tables[2].find_all('tr')[2:]:
            cols = row.find_all('td')
            cols = [ele.text.strip() for ele in cols]
            if len(cols)>1:
                subjects[cols[0]] = cols[-1]
            subjects["gpa"] = cols[0].split("\n")[-1]
    else:
        pass

    data_list.append(subjects)
    print(subjects)
# Out:
# Fetching Result of:  210621
# 200
# {'name': 'Muhammad Talha Ehtisham', 'roll_number': 210621, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'B-', 'F-23-Data Structures & Algorithms Lab-768': 'C+', 'F-23-Data Structures & Algorithms-767': 'C', 'F-23-Differential Equations-769': 'B+', 'F-23-Probability and Statistics-770': 'XW', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'C+', 'gpa': '2.18'}
#
# Fetching Result of:  220470
# 200
# {'name': 'Muhammad Abdullah Shaheer', 'roll_number': 220470, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'D', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'B-', 'F-23-Differential Equations-769': 'D', 'F-23-Probability and Statistics-770': 'C', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'B-', 'gpa': '2'}
#
# Fetching Result of:  220480
# 200
# {'name': 'Hafiz Muhammad Sami Ullah Khan', 'roll_number': 220480}
#
# Fetching Result of:  220536
# 200
# {'name': 'Syed Hashir Asim', 'roll_number': 220536, 'F-23-Computer Organization and Assembly Language Lab-774': 'B-', 'F-23-Computer Organization and Assembly Language-773': 'D', 'F-23-Data Structures & Algorithms Lab-768': 'B+', 'F-23-Data Structures & Algorithms-767': 'C-', 'F-23-Differential Equations-769': 'C', 'F-23-Probability and Statistics-770': 'D', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'D', 'gpa': '1.65'}
#
# Fetching Result of:  220952
# 200
# {'name': 'Bilal Abid', 'roll_number': 220952, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'D', 'F-23-Data Structures & Algorithms Lab-768': 'B', 'F-23-Data Structures & Algorithms-767': 'B', 'F-23-Differential Equations-769': 'B+', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'B-', 'gpa': '2.67'}
#
# Fetching Result of:  220953
# 200
# {'name': 'Jawad Ali Yousafzai', 'roll_number': 220953, 'F-23-Computer Organization and Assembly Language Lab-774': 'A-', 'F-23-Computer Organization and Assembly Language-773': 'C', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'C+', 'F-23-Differential Equations-769': 'A', 'F-23-Probability and Statistics-770': 'A-', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'B', 'gpa': '3.04'}
#
# Fetching Result of:  220955
# 200
# {'name': 'Ahad Saeed', 'roll_number': 220955, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'D', 'F-23-Data Structures & Algorithms Lab-768': 'B', 'F-23-Data Structures & Algorithms-767': 'C+', 'F-23-Differential Equations-769': 'B-', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'C+', 'gpa': '2.39'}
#
# Fetching Result of:  220958
# 200
# {'name': 'Aqil Ahmed', 'roll_number': 220958, 'F-23-Computer Organization and Assembly Language Lab-774': 'B+', 'F-23-Computer Organization and Assembly Language-773': 'B', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'B', 'F-23-Differential Equations-769': 'C+', 'F-23-Probability and Statistics-770': 'B-', 'F-23-Programming for Artificial Intelligence Lab-772': 'A', 'F-23-Programming for Artificial Intelligence-771': 'A', 'gpa': '3'}
#
# Fetching Result of:  220959
# 200
# {'name': 'Samreen Fatima', 'roll_number': 220959, 'F-23-Computer Organization and Assembly Language Lab-774': 'A-', 'F-23-Computer Organization and Assembly Language-773': 'A', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'B+', 'F-23-Differential Equations-769': 'A-', 'F-23-Probability and Statistics-770': 'A-', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'A', 'gpa': '3.63'}
#
# Fetching Result of:  220960
# 200
# {'name': 'Majid Hussain', 'roll_number': 220960, 'F-23-Computer Organization and Assembly Language Lab-774': 'B-', 'F-23-Computer Organization and Assembly Language-773': 'D', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'C', 'F-23-Differential Equations-769': 'C+', 'F-23-Probability and Statistics-770': 'C', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'B-', 'gpa': '2.1'}
#
# Fetching Result of:  220961
# 200
# {'name': 'Maham Sheikh', 'roll_number': 220961, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'C', 'F-23-Data Structures & Algorithms Lab-768': 'B', 'F-23-Data Structures & Algorithms-767': 'B', 'F-23-Differential Equations-769': 'B', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'C', 'gpa': '2.71'}
#
# Fetching Result of:  220962
# 200
# {'name': 'Muhammad Adrees', 'roll_number': 220962, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'B+', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'A-', 'F-23-Differential Equations-769': 'B+', 'F-23-Probability and Statistics-770': 'A-', 'F-23-Programming for Artificial Intelligence Lab-772': 'A-', 'F-23-Programming for Artificial Intelligence-771': 'A-', 'gpa': '3.45'}
#
# Fetching Result of:  220963
# 200
# {'name': 'Muhammad Saran Tariq', 'roll_number': 220963, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'B-', 'F-23-Data Structures & Algorithms Lab-768': 'B+', 'F-23-Data Structures & Algorithms-767': 'B+', 'F-23-Differential Equations-769': 'B+', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'B-', 'F-23-Programming for Artificial Intelligence-771': 'B', 'gpa': '3.06'}
#
# Fetching Result of:  220964
# 200
# {'name': 'Raqia Tauqir', 'roll_number': 220964, 'F-23-Computer Organization and Assembly Language Lab-774': 'A', 'F-23-Computer Organization and Assembly Language-773': 'B-', 'F-23-Data Structures & Algorithms Lab-768': 'B', 'F-23-Data Structures & Algorithms-767': 'B', 'F-23-Differential Equations-769': 'B+', 'F-23-Probability and Statistics-770': 'A-', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'B-', 'gpa': '3.14'}
#
# Fetching Result of:  220965
# 200
# {'name': 'Ahmed Abbasi', 'roll_number': 220965, 'F-23-Computer Organization and Assembly Language Lab-774': 'B+', 'F-23-Computer Organization and Assembly Language-773': 'C+', 'F-23-Data Structures & Algorithms Lab-768': 'A', 'F-23-Data Structures & Algorithms-767': 'B', 'F-23-Differential Equations-769': 'C-', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'B-', 'gpa': '2.69'}
#
# Fetching Result of:  220966
# 200
# {'name': 'Shaheryar Shakeel', 'roll_number': 220966, 'F-23-Computer Organization and Assembly Language Lab-774': 'A', 'F-23-Computer Organization and Assembly Language-773': 'A-', 'F-23-Data Structures & Algorithms Lab-768': 'A', 'F-23-Data Structures & Algorithms-767': 'A', 'F-23-Differential Equations-769': 'A-', 'F-23-Probability and Statistics-770': 'A-', 'F-23-Programming for Artificial Intelligence Lab-772': 'A', 'F-23-Programming for Artificial Intelligence-771': 'A', 'gpa': '3.83'}
#
# Fetching Result of:  220967
# 200
# {'name': 'Aleeza Asghar', 'roll_number': 220967, 'F-23-Computer Organization and Assembly Language Lab-774': 'A', 'F-23-Computer Organization and Assembly Language-773': 'A-', 'F-23-Data Structures & Algorithms Lab-768': 'A', 'F-23-Data Structures & Algorithms-767': 'A', 'F-23-Differential Equations-769': 'A-', 'F-23-Probability and Statistics-770': 'A-', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'B', 'gpa': '3.67'}
#
# Fetching Result of:  220968
# 200
# {'name': 'Eisha Iman', 'roll_number': 220968, 'F-23-Computer Organization and Assembly Language Lab-774': 'B+', 'F-23-Computer Organization and Assembly Language-773': 'B-', 'F-23-Data Structures & Algorithms Lab-768': 'B+', 'F-23-Data Structures & Algorithms-767': 'B', 'F-23-Differential Equations-769': 'B+', 'F-23-Probability and Statistics-770': 'B+', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'C+', 'gpa': '3.02'}
#
# Fetching Result of:  220969
# 200
# {'name': 'Muhammad Qasim Haider Mirza', 'roll_number': 220969, 'F-23-Computer Organization and Assembly Language Lab-774': 'B-', 'F-23-Computer Organization and Assembly Language-773': 'B-', 'F-23-Data Structures & Algorithms Lab-768': 'B', 'F-23-Data Structures & Algorithms-767': 'B-', 'F-23-Differential Equations-769': 'C', 'F-23-Probability and Statistics-770': 'B-', 'F-23-Programming for Artificial Intelligence Lab-772': 'B-', 'F-23-Programming for Artificial Intelligence-771': 'B+', 'gpa': '2.65'}
#
# Fetching Result of:  220970
# 200
# {'name': 'Taiba Qadri', 'roll_number': 220970, 'F-23-Computer Organization and Assembly Language Lab-774': 'B+', 'F-23-Computer Organization and Assembly Language-773': 'C+', 'F-23-Data Structures & Algorithms Lab-768': 'B', 'F-23-Data Structures & Algorithms-767': 'B', 'F-23-Differential Equations-769': 'B+', 'F-23-Probability and Statistics-770': 'B+', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'B-', 'gpa': '2.98'}
#
# Fetching Result of:  220971
# 200
# {'name': 'Abdul Moiz Abbasi', 'roll_number': 220971, 'F-23-Computer Organization and Assembly Language Lab-774': 'A-', 'F-23-Computer Organization and Assembly Language-773': 'C+', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'B-', 'F-23-Differential Equations-769': 'C', 'F-23-Probability and Statistics-770': 'B-', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'A-', 'gpa': '2.71'}
#
# Fetching Result of:  220973
# 200
# {'name': 'Warda Akram', 'roll_number': 220973, 'F-23-Computer Organization and Assembly Language Lab-774': 'C+', 'F-23-Computer Organization and Assembly Language-773': 'D', 'F-23-Data Structures & Algorithms Lab-768': 'C', 'F-23-Data Structures & Algorithms-767': 'C-', 'F-23-Differential Equations-769': 'C+', 'F-23-Probability and Statistics-770': 'C', 'F-23-Programming for Artificial Intelligence Lab-772': 'C+', 'F-23-Programming for Artificial Intelligence-771': 'F', 'gpa': '1.63'}
#
# Fetching Result of:  220974
# 200
# {'name': 'Waleed Shehzad', 'roll_number': 220974, 'F-23-Computer Organization and Assembly Language Lab-774': 'A-', 'F-23-Computer Organization and Assembly Language-773': 'C-', 'F-23-Data Structures & Algorithms Lab-768': 'B', 'F-23-Data Structures & Algorithms-767': 'B-', 'F-23-Differential Equations-769': 'C', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'B+', 'gpa': '2.63'}
#
# Fetching Result of:  220975
# 200
# {'name': 'Azlan Malik', 'roll_number': 220975, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'C-', 'F-23-Data Structures & Algorithms Lab-768': 'C', 'F-23-Data Structures & Algorithms-767': 'C+', 'F-23-Differential Equations-769': 'B', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'C+', 'F-23-Programming for Artificial Intelligence-771': 'C+', 'gpa': '2.47'}
#
# Fetching Result of:  220976
# 200
# {'name': 'Laraib Irfan', 'roll_number': 220976, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'C-', 'F-23-Data Structures & Algorithms Lab-768': 'A', 'F-23-Data Structures & Algorithms-767': 'B-', 'F-23-Differential Equations-769': 'C+', 'F-23-Probability and Statistics-770': 'B-', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'C-', 'gpa': '2.43'}
#
# Fetching Result of:  220977
# 200
# {'name': 'Mahay Muneeb', 'roll_number': 220977, 'F-23-Data Structures & Algorithms Lab-768': 'B+', 'F-23-Data Structures & Algorithms-767': 'C', 'F-23-Differential Equations-769': 'C+', 'F-23-Digital Logic Design Laboratory-387': 'D', 'F-23-Digital Logic Design-386': 'C-', 'F-23-Probability and Statistics-770': 'C', 'F-23-Programming for Artificial Intelligence Lab-772': 'B-', 'F-23-Programming for Artificial Intelligence-771': 'C+', 'gpa': '2.1'}
#
# Fetching Result of:  220978
# 200
# {'name': 'Waqar Ali', 'roll_number': 220978, 'F-23-Computer Organization and Assembly Language Lab-774': 'A-', 'F-23-Computer Organization and Assembly Language-773': 'C-', 'F-23-Data Structures & Algorithms Lab-768': 'B+', 'F-23-Data Structures & Algorithms-767': 'C', 'F-23-Differential Equations-769': 'A', 'F-23-Probability and Statistics-770': 'A-', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'C', 'gpa': '2.84'}
#
# Fetching Result of:  220980
# 200
# {'name': 'Malaika Mohsin', 'roll_number': 220980, 'F-23-Computer Organization and Assembly Language Lab-774': 'C+', 'F-23-Computer Organization and Assembly Language-773': 'D', 'F-23-Data Structures & Algorithms Lab-768': 'C', 'F-23-Data Structures & Algorithms-767': 'C', 'F-23-Differential Equations-769': 'C', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'C', 'F-23-Programming for Artificial Intelligence-771': 'C-', 'gpa': '1.98'}
#
# Fetching Result of:  220981
# 200
# {'name': 'Shoaib Rasool', 'roll_number': 220981, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'C-', 'F-23-Data Structures & Algorithms Lab-768': 'B', 'F-23-Data Structures & Algorithms-767': 'C+', 'F-23-Differential Equations-769': 'C', 'F-23-Probability and Statistics-770': 'C+', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'B', 'gpa': '2.35'}
#
# Fetching Result of:  220982
# 200
# {'name': 'Abdual Subhan Tariq', 'roll_number': 220982, 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'C-', 'F-23-Differential Equations-769': 'B-', 'F-23-Digital Logic Design Laboratory-387': 'D', 'F-23-Digital Logic Design-386': 'C-', 'F-23-Probability and Statistics-770': 'C', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'C-', 'gpa': '2'}
#
# Fetching Result of:  220983
# 200
# {'name': 'Nashrah Ul Emaan', 'roll_number': 220983, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'C', 'F-23-Data Structures & Algorithms Lab-768': 'B', 'F-23-Data Structures & Algorithms-767': 'A-', 'F-23-Differential Equations-769': 'B', 'F-23-Probability and Statistics-770': 'B-', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'A-', 'gpa': '2.96'}
#
# Fetching Result of:  220984
# 200
# {'name': 'Muhammad Dawood', 'roll_number': 220984, 'F-23-Computer Organization and Assembly Language Lab-774': 'B+', 'F-23-Computer Organization and Assembly Language-773': 'C+', 'F-23-Data Structures & Algorithms Lab-768': 'B', 'F-23-Data Structures & Algorithms-767': 'B', 'F-23-Differential Equations-769': 'C-', 'F-23-Probability and Statistics-770': 'B-', 'F-23-Programming for Artificial Intelligence Lab-772': 'A-', 'F-23-Programming for Artificial Intelligence-771': 'A', 'gpa': '2.77'}
#
# Fetching Result of:  220985
# 200
# {'name': 'Insha Nadeem', 'roll_number': 220985, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'C+', 'F-23-Data Structures & Algorithms Lab-768': 'B+', 'F-23-Data Structures & Algorithms-767': 'A-', 'F-23-Differential Equations-769': 'B+', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'B', 'gpa': '3.1'}
#
# Fetching Result of:  220986
# 200
# {'name': 'Emaan Yawer Shahzad', 'roll_number': 220986, 'F-23-Computer Organization and Assembly Language Lab-774': 'B-', 'F-23-Computer Organization and Assembly Language-773': 'D', 'F-23-Data Structures & Algorithms Lab-768': 'B+', 'F-23-Data Structures & Algorithms-767': 'C+', 'F-23-Differential Equations-769': 'B', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'B-', 'F-23-Programming for Artificial Intelligence-771': 'C-', 'gpa': '2.35'}
#
# Fetching Result of:  220989
# 200
# {'name': 'Talha', 'roll_number': 220989, 'F-23-Computer Organization and Assembly Language Lab-774': 'B-', 'F-23-Computer Organization and Assembly Language-773': 'B-', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'B', 'F-23-Differential Equations-769': 'B+', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'A', 'F-23-Programming for Artificial Intelligence-771': 'B+', 'gpa': '3.06'}
#
# Fetching Result of:  220990
# 200
# {'name': 'Muhammad Arshad', 'roll_number': 220990, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'C+', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'A', 'F-23-Differential Equations-769': 'B', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'A-', 'gpa': '3.14'}
#
# Fetching Result of:  220992
# 200
# {'name': 'Safeer Ahmad', 'roll_number': 220992, 'F-23-Computer Organization and Assembly Language Lab-774': 'B-', 'F-23-Computer Organization and Assembly Language-773': 'C+', 'F-23-Data Structures & Algorithms Lab-768': 'C', 'F-23-Data Structures & Algorithms-767': 'B', 'F-23-Differential Equations-769': 'B', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'C+', 'F-23-Programming for Artificial Intelligence-771': 'B-', 'gpa': '2.73'}
#
# Fetching Result of:  220993
# 200
# {'name': 'Fatima Binte Bilal', 'roll_number': 220993, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'B-', 'F-23-Data Structures & Algorithms Lab-768': 'B', 'F-23-Data Structures & Algorithms-767': 'B-', 'F-23-Differential Equations-769': 'C+', 'F-23-Probability and Statistics-770': 'B+', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'B+', 'gpa': '2.86'}
#
# Fetching Result of:  220997
# 200
# {'name': 'Wasif Zafar', 'roll_number': 220997}
#
# Fetching Result of:  220998
# 200
# {'name': 'Khizra', 'roll_number': 220998, 'F-23-Computer Organization and Assembly Language Lab-774': 'B-', 'F-23-Computer Organization and Assembly Language-773': 'C-', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'C', 'F-23-Differential Equations-769': 'B', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'C', 'F-23-Programming for Artificial Intelligence-771': 'C', 'gpa': '2.37'}
#
# Fetching Result of:  221000
# 200
# {'name': 'Badar Khan', 'roll_number': 221000, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'C-', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'C+', 'F-23-Differential Equations-769': 'C-', 'F-23-Probability and Statistics-770': 'C-', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'B', 'gpa': '2.18'}
#
# Fetching Result of:  221001
# 200
# {'name': 'Muhammad Awaiz Qayyum Malik', 'roll_number': 221001, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'C-', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'C+', 'F-23-Differential Equations-769': 'C', 'F-23-Probability and Statistics-770': 'C+', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'B+', 'gpa': '2.37'}
#
# Fetching Result of:  221002
# 200
# {'name': 'Rayyan Ali Shah', 'roll_number': 221002, 'F-23-Computer Organization and Assembly Language Lab-774': 'B-', 'F-23-Computer Organization and Assembly Language-773': 'D', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'C', 'F-23-Differential Equations-769': 'C+', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'C', 'gpa': '2.22'}
#
# Fetching Result of:  221003
# 200
# {'name': 'Muhammad Amjad Mehmood', 'roll_number': 221003, 'F-23-Computer Organization and Assembly Language Lab-774': 'B-', 'F-23-Computer Organization and Assembly Language-773': 'C', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'C+', 'F-23-Differential Equations-769': 'C+', 'F-23-Probability and Statistics-770': 'B-', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'B-', 'gpa': '2.47'}
#
# Fetching Result of:  221004
# 200
# {'name': 'Aqsa Junaid', 'roll_number': 221004, 'F-23-Computer Organization and Assembly Language Lab-774': 'B+', 'F-23-Computer Organization and Assembly Language-773': 'A', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'A', 'F-23-Differential Equations-769': 'A', 'F-23-Probability and Statistics-770': 'A', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'A-', 'gpa': '3.8'}
#
# Fetching Result of:  221005
# 200
# {'name': 'Ahmed Soban', 'roll_number': 221005, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'C+', 'F-23-Data Structures & Algorithms Lab-768': 'B+', 'F-23-Data Structures & Algorithms-767': 'C+', 'F-23-Differential Equations-769': 'F', 'F-23-Probability and Statistics-770': 'C', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'B-', 'gpa': '2.06'}
#
# Fetching Result of:  221006
# 200
# {'name': 'Raja Muhammad Hashir', 'roll_number': 221006, 'F-23-Computer Organization and Assembly Language Lab-774': 'B-', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'B+', 'F-23-Differential Equations-769': 'B+', 'F-23-Probability and Statistics-770': 'A', 'F-23-Programming for Artificial Intelligence Lab-772': 'A', 'F-23-Programming for Artificial Intelligence-771': 'A', 'gpa': '3.52'}
#
# Fetching Result of:  221574
# 200
# {'name': 'Dawood Haider Chaudhary', 'roll_number': 221574, 'F-23-Computer Organization and Assembly Language Lab-774': 'B', 'F-23-Computer Organization and Assembly Language-773': 'C', 'F-23-Data Structures & Algorithms Lab-768': 'C+', 'F-23-Data Structures & Algorithms-767': 'C+', 'F-23-Differential Equations-769': 'B-', 'F-23-Probability and Statistics-770': 'B', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'B-', 'gpa': '2.57'}
#
# Fetching Result of:  222550
# 200
# {'name': 'Muhammad Ahmed', 'roll_number': 222550, 'F-23-Computer Organization and Assembly Language Lab-774': 'B-', 'F-23-Computer Organization and Assembly Language-773': 'C-', 'F-23-Data Structures & Algorithms Lab-768': 'A-', 'F-23-Data Structures & Algorithms-767': 'C+', 'F-23-Differential Equations-769': 'B-', 'F-23-Probability and Statistics-770': 'B-', 'F-23-Programming for Artificial Intelligence Lab-772': 'B', 'F-23-Programming for Artificial Intelligence-771': 'C', 'gpa': '2.43'}
#
# Fetching Result of:  222668
# 200
# {'name': 'Muzaqqa Shoaib', 'roll_number': 222668, 'F-23-Computer Organization and Assembly Language Lab-774': 'B+', 'F-23-Computer Organization and Assembly Language-773': 'C', 'F-23-Differential Equations-769': 'C+', 'F-23-Foundational Mathematics-2080': 'A-', 'F-23-Programming for Artificial Intelligence Lab-772': 'XF', 'F-23-Programming for Artificial Intelligence-771': 'XF', 'gpa': '2.21'}
#
# Fetching Result of:  222669
# 200
# {'name': 'Laiba Masood', 'roll_number': 222669, 'F-23-Computer Organization and Assembly Language Lab-774': 'B+', 'F-23-Computer Organization and Assembly Language-773': 'B-', 'F-23-Data Structures & Algorithms Lab-768': 'B-', 'F-23-Data Structures & Algorithms-767': 'B', 'F-23-Differential Equations-769': 'A', 'F-23-Programming for Artificial Intelligence Lab-772': 'B+', 'F-23-Programming for Artificial Intelligence-771': 'B', 'gpa': '3.17'}

# %%
dataframe = pd.DataFrame(data_list)dataframe

# %%
dataframe.to_csv("BSAI-united.csv")

# %%
dataframe
# Out:
#                               name  roll_number  \
# 0          Muhammad Talha Ehtisham       210621
# 1        Muhammad Abdullah Shaheer       220470
# 2   Hafiz Muhammad Sami Ullah Khan       220480
# 3                 Syed Hashir Asim       220536
# 4                       Bilal Abid       220952
# 5              Jawad Ali Yousafzai       220953
# 6                       Ahad Saeed       220955
# 7                       Aqil Ahmed       220958
# 8                   Samreen Fatima       220959
# 9                    Majid Hussain       220960
# 10                    Maham Sheikh       220961
# 11                 Muhammad Adrees       220962
# 12            Muhammad Saran Tariq       220963
# 13                    Raqia Tauqir       220964
# 14                    Ahmed Abbasi       220965
# 15               Shaheryar Shakeel       220966
# 16                   Aleeza Asghar       220967
# 17                      Eisha Iman       220968
# 18     Muhammad Qasim Haider Mirza       220969
# 19                     Taiba Qadri       220970
# 20               Abdul Moiz Abbasi       220971
# 21                     Warda Akram       220973
# 22                  Waleed Shehzad       220974
# 23                     Azlan Malik       220975
# 24                    Laraib Irfan       220976
# 25                    Mahay Muneeb       220977
# 26                       Waqar Ali       220978
# 27                  Malaika Mohsin       220980
# 28                   Shoaib Rasool       220981
# 29             Abdual Subhan Tariq       220982
# 30                Nashrah Ul Emaan       220983
# 31                 Muhammad Dawood       220984
# 32                    Insha Nadeem       220985
# 33             Emaan Yawer Shahzad       220986
# 34                           Talha       220989
# 35                 Muhammad Arshad       220990
# 36                    Safeer Ahmad       220992
# 37              Fatima Binte Bilal       220993
# 38                     Wasif Zafar       220997
# 39                          Khizra       220998
# 40                      Badar Khan       221000
# 41     Muhammad Awaiz Qayyum Malik       221001
# 42                 Rayyan Ali Shah       221002
# 43          Muhammad Amjad Mehmood       221003
# 44                     Aqsa Junaid       221004
# 45                     Ahmed Soban       221005
# 46            Raja Muhammad Hashir       221006
# 47         Dawood Haider Chaudhary       221574
# 48                  Muhammad Ahmed       222550
# 49                  Muzaqqa Shoaib       222668
# 50                    Laiba Masood       222669
#
#    F-23-Computer Organization and Assembly Language Lab-774  \
# 0                                                   B
# 1                                                   B
# 2                                                 NaN
# 3                                                  B-
# 4                                                   B
# 5                                                  A-
# 6                                                   B
# 7                                                  B+
# 8                                                  A-
# 9                                                  B-
# 10                                                  B
# 11                                                  B
# 12                                                  B
# 13                                                  A
# 14                                                 B+
# 15                                                  A
# 16                                                  A
# 17                                                 B+
# 18                                                 B-
# 19                                                 B+
# 20                                                 A-
# 21                                                 C+
# 22                                                 A-
# 23                                                  B
# 24                                                  B
# 25                                                NaN
# 26                                                 A-
# 27                                                 C+
# 28                                                  B
# 29                                                NaN
# 30                                                  B
# 31                                                 B+
# 32                                                  B
# 33                                                 B-
# 34                                                 B-
# 35                                                  B
# 36                                                 B-
# 37                                                  B
# 38                                                NaN
# 39                                                 B-
# 40                                                  B
# 41                                                  B
# 42                                                 B-
# 43                                                 B-
# 44                                                 B+
# 45                                                  B
# 46                                                 B-
# 47                                                  B
# 48                                                 B-
# 49                                                 B+
# 50                                                 B+
#
#    F-23-Computer Organization and Assembly Language-773  \
# 0                                                  B-
# 1                                                   D
# 2                                                 NaN
# 3                                                   D
# 4                                                   D
# 5                                                   C
# 6                                                   D
# 7                                                   B
# 8                                                   A
# 9                                                   D
# 10                                                  C
# 11                                                 B+
# 12                                                 B-
# 13                                                 B-
# 14                                                 C+
# 15                                                 A-
# 16                                                 A-
# 17                                                 B-
# 18                                                 B-
# 19                                                 C+
# 20                                                 C+
# 21                                                  D
# 22                                                 C-
# 23                                                 C-
# 24                                                 C-
# 25                                                NaN
# 26                                                 C-
# 27                                                  D
# 28                                                 C-
# 29                                                NaN
# 30                                                  C
# 31                                                 C+
# 32                                                 C+
# 33                                                  D
# 34                                                 B-
# 35                                                 C+
# 36                                                 C+
# 37                                                 B-
# 38                                                NaN
# 39                                                 C-
# 40                                                 C-
# 41                                                 C-
# 42                                                  D
# 43                                                  C
# 44                                                  A
# 45                                                 C+
# 46                                                NaN
# 47                                                  C
# 48                                                 C-
# 49                                                  C
# 50                                                 B-
#
#    F-23-Data Structures & Algorithms Lab-768  \
# 0                                         C+
# 1                                         B-
# 2                                        NaN
# 3                                         B+
# 4                                          B
# 5                                         B-
# 6                                          B
# 7                                         B-
# 8                                         B-
# 9                                         B-
# 10                                         B
# 11                                        B-
# 12                                        B+
# 13                                         B
# 14                                         A
# 15                                         A
# 16                                         A
# 17                                        B+
# 18                                         B
# 19                                         B
# 20                                        B-
# 21                                         C
# 22                                         B
# 23                                         C
# 24                                         A
# 25                                        B+
# 26                                        B+
# 27                                         C
# 28                                         B
# 29                                        B-
# 30                                         B
# 31                                         B
# 32                                        B+
# 33                                        B+
# 34                                        B-
# 35                                        B-
# 36                                         C
# 37                                         B
# 38                                       NaN
# 39                                        B-
# 40                                        B-
# 41                                        B-
# 42                                        B-
# 43                                        B-
# 44                                        B-
# 45                                        B+
# 46                                        B-
# 47                                        C+
# 48                                        A-
# 49                                       NaN
# 50                                        B-
#
#    F-23-Data Structures & Algorithms-767 F-23-Differential Equations-769  \
# 0                                      C                              B+
# 1                                     B-                               D
# 2                                    NaN                             NaN
# 3                                     C-                               C
# 4                                      B                              B+
# 5                                     C+                               A
# 6                                     C+                              B-
# 7                                      B                              C+
# 8                                     B+                              A-
# 9                                      C                              C+
# 10                                     B                               B
# 11                                    A-                              B+
# 12                                    B+                              B+
# 13                                     B                              B+
# 14                                     B                              C-
# 15                                     A                              A-
# 16                                     A                              A-
# 17                                     B                              B+
# 18                                    B-                               C
# 19                                     B                              B+
# 20                                    B-                               C
# 21                                    C-                              C+
# 22                                    B-                               C
# 23                                    C+                               B
# 24                                    B-                              C+
# 25                                     C                              C+
# 26                                     C                               A
# 27                                     C                               C
# 28                                    C+                               C
# 29                                    C-                              B-
# 30                                    A-                               B
# 31                                     B                              C-
# 32                                    A-                              B+
# 33                                    C+                               B
# 34                                     B                              B+
# 35                                     A                               B
# 36                                     B                               B
# 37                                    B-                              C+
# 38                                   NaN                             NaN
# 39                                     C                               B
# 40                                    C+                              C-
# 41                                    C+                               C
# 42                                     C                              C+
# 43                                    C+                              C+
# 44                                     A                               A
# 45                                    C+                               F
# 46                                    B+                              B+
# 47                                    C+                              B-
# 48                                    C+                              B-
# 49                                   NaN                              C+
# 50                                     B                               A
#
#    F-23-Probability and Statistics-770  \
# 0                                   XW
# 1                                    C
# 2                                  NaN
# 3                                    D
# 4                                    B
# 5                                   A-
# 6                                    B
# 7                                   B-
# 8                                   A-
# 9                                    C
# 10                                   B
# 11                                  A-
# 12                                   B
# 13                                  A-
# 14                                   B
# 15                                  A-
# 16                                  A-
# 17                                  B+
# 18                                  B-
# 19                                  B+
# 20                                  B-
# 21                                   C
# 22                                   B
# 23                                   B
# 24                                  B-
# 25                                   C
# 26                                  A-
# 27                                   B
# 28                                  C+
# 29                                   C
# 30                                  B-
# 31                                  B-
# 32                                   B
# 33                                   B
# 34                                   B
# 35                                   B
# 36                                   B
# 37                                  B+
# 38                                 NaN
# 39                                   B
# 40                                  C-
# 41                                  C+
# 42                                   B
# 43                                  B-
# 44                                   A
# 45                                   C
# 46                                   A
# 47                                   B
# 48                                  B-
# 49                                 NaN
# 50                                 NaN
#
#    F-23-Programming for Artificial Intelligence Lab-772  \
# 0                                                   B
# 1                                                   B
# 2                                                 NaN
# 3                                                   B
# 4                                                   B
# 5                                                  B+
# 6                                                   B
# 7                                                   A
# 8                                                  B+
# 9                                                   B
# 10                                                  B
# 11                                                 A-
# 12                                                 B-
# 13                                                  B
# 14                                                  B
# 15                                                  A
# 16                                                 B+
# 17                                                  B
# 18                                                 B-
# 19                                                  B
# 20                                                 B+
# 21                                                 C+
# 22                                                 B+
# 23                                                 C+
# 24                                                  B
# 25                                                 B-
# 26                                                 B+
# 27                                                  C
# 28                                                  B
# 29                                                  B
# 30                                                  B
# 31                                                 A-
# 32                                                 B+
# 33                                                 B-
# 34                                                  A
# 35                                                 B+
# 36                                                 C+
# 37                                                  B
# 38                                                NaN
# 39                                                  C
# 40                                                 B+
# 41                                                  B
# 42                                                 B+
# 43                                                 B+
# 44                                                 B+
# 45                                                 B+
# 46                                                  A
# 47                                                  B
# 48                                                  B
# 49                                                 XF
# 50                                                 B+
#
#    F-23-Programming for Artificial Intelligence-771   gpa  \
# 0                                                C+  2.18
# 1                                                B-     2
# 2                                               NaN   NaN
# 3                                                 D  1.65
# 4                                                B-  2.67
# 5                                                 B  3.04
# 6                                                C+  2.39
# 7                                                 A     3
# 8                                                 A  3.63
# 9                                                B-   2.1
# 10                                                C  2.71
# 11                                               A-  3.45
# 12                                                B  3.06
# 13                                               B-  3.14
# 14                                               B-  2.69
# 15                                                A  3.83
# 16                                                B  3.67
# 17                                               C+  3.02
# 18                                               B+  2.65
# 19                                               B-  2.98
# 20                                               A-  2.71
# 21                                                F  1.63
# 22                                               B+  2.63
# 23                                               C+  2.47
# 24                                               C-  2.43
# 25                                               C+   2.1
# 26                                                C  2.84
# 27                                               C-  1.98
# 28                                                B  2.35
# 29                                               C-     2
# 30                                               A-  2.96
# 31                                                A  2.77
# 32                                                B   3.1
# 33                                               C-  2.35
# 34                                               B+  3.06
# 35                                               A-  3.14
# 36                                               B-  2.73
# 37                                               B+  2.86
# 38                                              NaN   NaN
# 39                                                C  2.37
# 40                                                B  2.18
# 41                                               B+  2.37
# 42                                                C  2.22
# 43                                               B-  2.47
# 44                                               A-   3.8
# 45                                               B-  2.06
# 46                                                A  3.52
# 47                                               B-  2.57
# 48                                                C  2.43
# 49                                               XF  2.21
# 50                                                B  3.17
#
#    F-23-Digital Logic Design Laboratory-387 F-23-Digital Logic Design-386  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
# 5                                       NaN                           NaN
# 6                                       NaN                           NaN
# 7                                       NaN                           NaN
# 8                                       NaN                           NaN
# 9                                       NaN                           NaN
# 10                                      NaN                           NaN
# 11                                      NaN                           NaN
# 12                                      NaN                           NaN
# 13                                      NaN                           NaN
# 14                                      NaN                           NaN
# 15                                      NaN                           NaN
# 16                                      NaN                           NaN
# 17                                      NaN                           NaN
# 18                                      NaN                           NaN
# 19                                      NaN                           NaN
# 20                                      NaN                           NaN
# 21                                      NaN                           NaN
# 22                                      NaN                           NaN
# 23                                      NaN                           NaN
# 24                                      NaN                           NaN
# 25                                        D                            C-
# 26                                      NaN                           NaN
# 27                                      NaN                           NaN
# 28                                      NaN                           NaN
# 29                                        D                            C-
# 30                                      NaN                           NaN
# 31                                      NaN                           NaN
# 32                                      NaN                           NaN
# 33                                      NaN                           NaN
# 34                                      NaN                           NaN
# 35                                      NaN                           NaN
# 36                                      NaN                           NaN
# 37                                      NaN                           NaN
# 38                                      NaN                           NaN
# 39                                      NaN                           NaN
# 40                                      NaN                           NaN
# 41                                      NaN                           NaN
# 42                                      NaN                           NaN
# 43                                      NaN                           NaN
# 44                                      NaN                           NaN
# 45                                      NaN                           NaN
# 46                                      NaN                           NaN
# 47                                      NaN                           NaN
# 48                                      NaN                           NaN
# 49                                      NaN                           NaN
# 50                                      NaN                           NaN
#
#    F-23-Foundational Mathematics-2080
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                                NaN
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                                NaN
# 18                                NaN
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                                NaN
# 30                                NaN
# 31                                NaN
# 32                                NaN
# 33                                NaN
# 34                                NaN
# 35                                NaN
# 36                                NaN
# 37                                NaN
# 38                                NaN
# 39                                NaN
# 40                                NaN
# 41                                NaN
# 42                                NaN
# 43                                NaN
# 44                                NaN
# 45                                NaN
# 46                                NaN
# 47                                NaN
# 48                                NaN
# 49                                 A-
# 50                                NaN

# %%
sns.countplot(x='F-23-Computer Organization and Assembly Language-773', data=dataframe)
plt.xlabel('Values')
plt.ylabel('Count')

# Display the plot
plt.show()

# %%
sns.countplot(x='F-23-Programming for Artificial Intelligence-771', data=dataframe)
plt.xlabel('Values')
plt.ylabel('Count')
plt.show()

# %%
selected_row = dataframe[dataframe["roll_number"] == 221001]
selected_row = selected_row.dropna(axis=1, how='all')

# Plot the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=selected_row.columns[2:], y=selected_row.values.flatten()[2:])
plt.xlabel('Subjects')
plt.ylabel('Grades')
plt.title(f'Grades for roll_number = 221001')
plt.show()

# %%
df_sorted = dataframe.sort_values(by='gpa', ascending=False)
new_df = df_sorted.iloc[:, [0, -4]].dropna(axis=1, how='all')
new_df = new_df.reset_index(drop=True)
new_df
# Out:
#                               name   gpa
# 0                Shaheryar Shakeel  3.83
# 1                      Aqsa Junaid   3.8
# 2                    Aleeza Asghar  3.67
# 3                   Samreen Fatima  3.63
# 4             Raja Muhammad Hashir  3.52
# 5                  Muhammad Adrees  3.45
# 6                     Laiba Masood  3.17
# 7                  Muhammad Arshad  3.14
# 8                     Raqia Tauqir  3.14
# 9                     Insha Nadeem   3.1
# 10                           Talha  3.06
# 11            Muhammad Saran Tariq  3.06
# 12             Jawad Ali Yousafzai  3.04
# 13                      Eisha Iman  3.02
# 14                      Aqil Ahmed     3
# 15                     Taiba Qadri  2.98
# 16                Nashrah Ul Emaan  2.96
# 17              Fatima Binte Bilal  2.86
# 18                       Waqar Ali  2.84
# 19                 Muhammad Dawood  2.77
# 20                    Safeer Ahmad  2.73
# 21               Abdul Moiz Abbasi  2.71
# 22                    Maham Sheikh  2.71
# 23                    Ahmed Abbasi  2.69
# 24                      Bilal Abid  2.67
# 25     Muhammad Qasim Haider Mirza  2.65
# 26                  Waleed Shehzad  2.63
# 27         Dawood Haider Chaudhary  2.57
# 28                     Azlan Malik  2.47
# 29          Muhammad Amjad Mehmood  2.47
# 30                    Laraib Irfan  2.43
# 31                  Muhammad Ahmed  2.43
# 32                      Ahad Saeed  2.39
# 33     Muhammad Awaiz Qayyum Malik  2.37
# 34                          Khizra  2.37
# 35                   Shoaib Rasool  2.35
# 36             Emaan Yawer Shahzad  2.35
# 37                 Rayyan Ali Shah  2.22
# 38                  Muzaqqa Shoaib  2.21
# 39         Muhammad Talha Ehtisham  2.18
# 40                      Badar Khan  2.18
# 41                   Majid Hussain   2.1
# 42                    Mahay Muneeb   2.1
# 43                     Ahmed Soban  2.06
# 44             Abdual Subhan Tariq     2
# 45       Muhammad Abdullah Shaheer     2
# 46                  Malaika Mohsin  1.98
# 47                Syed Hashir Asim  1.65
# 48                     Warda Akram  1.63
# 49  Hafiz Muhammad Sami Ullah Khan   NaN
# 50                     Wasif Zafar   NaN

# %%
df_sorted = dataframe.sort_values(by='gpa', ascending=True)
new_df = df_sorted.iloc[:, [0, -4]].dropna(axis=1, how='all')
new_df = new_df.reset_index(drop=True)
new_df
# Out:
#                               name   gpa
# 0                      Warda Akram  1.63
# 1                 Syed Hashir Asim  1.65
# 2                   Malaika Mohsin  1.98
# 3        Muhammad Abdullah Shaheer     2
# 4              Abdual Subhan Tariq     2
# 5                      Ahmed Soban  2.06
# 6                     Mahay Muneeb   2.1
# 7                    Majid Hussain   2.1
# 8                       Badar Khan  2.18
# 9          Muhammad Talha Ehtisham  2.18
# 10                  Muzaqqa Shoaib  2.21
# 11                 Rayyan Ali Shah  2.22
# 12                   Shoaib Rasool  2.35
# 13             Emaan Yawer Shahzad  2.35
# 14     Muhammad Awaiz Qayyum Malik  2.37
# 15                          Khizra  2.37
# 16                      Ahad Saeed  2.39
# 17                  Muhammad Ahmed  2.43
# 18                    Laraib Irfan  2.43
# 19          Muhammad Amjad Mehmood  2.47
# 20                     Azlan Malik  2.47
# 21         Dawood Haider Chaudhary  2.57
# 22                  Waleed Shehzad  2.63
# 23     Muhammad Qasim Haider Mirza  2.65
# 24                      Bilal Abid  2.67
# 25                    Ahmed Abbasi  2.69
# 26               Abdul Moiz Abbasi  2.71
# 27                    Maham Sheikh  2.71
# 28                    Safeer Ahmad  2.73
# 29                 Muhammad Dawood  2.77
# 30                       Waqar Ali  2.84
# 31              Fatima Binte Bilal  2.86
# 32                Nashrah Ul Emaan  2.96
# 33                     Taiba Qadri  2.98
# 34                      Aqil Ahmed     3
# 35                      Eisha Iman  3.02
# 36             Jawad Ali Yousafzai  3.04
# 37                           Talha  3.06
# 38            Muhammad Saran Tariq  3.06
# 39                    Insha Nadeem   3.1
# 40                 Muhammad Arshad  3.14
# 41                    Raqia Tauqir  3.14
# 42                    Laiba Masood  3.17
# 43                 Muhammad Adrees  3.45
# 44            Raja Muhammad Hashir  3.52
# 45                  Samreen Fatima  3.63
# 46                   Aleeza Asghar  3.67
# 47                     Aqsa Junaid   3.8
# 48               Shaheryar Shakeel  3.83
# 49  Hafiz Muhammad Sami Ullah Khan   NaN
# 50                     Wasif Zafar   NaN
